# %%
import cv2
from google.colab.patches import cv2_imshow

file = '/content/drive/MyDrive/Colab Notebooks/DataSets/face.jpg'   # drive needs to be mounted first
img = cv2.imread(file)

face_classifier = cv2.CascadeClassifier(cv2.data.haarcascades + 'haarcascade_frontalface_default.xml')
faces = face_classifier.detectMultiScale(img, 1.3, 5)
for (x, y, w, h) in faces:
  cv2.rectangle(img, (x, y), (x+w, y+h), (225, 0, 0), 2)     # img or img_grayed, 위치, 크기, 색상, 두께

cv2_imshow(img)
cv2.waitKey()
cv2.imwrite("Face detected.jpg", img)
# Out:
# <PIL.Image.Image image mode=RGB size=275x183 at 0x7F2CCF34D2E0>
# True
